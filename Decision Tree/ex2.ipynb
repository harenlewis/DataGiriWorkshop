# %%
import numpy as np
import pandas as pd

# %%
loan = pd.read_csv('loan_prediction.csv')

# %%
loan.groupby('Loan_Status').count()
# Out:
#              ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_Status
# 0                        192                192         192               192
# 1                        422                422         422               422
#
#              Credit_History
# Loan_Status
# 0                       192
# 1                       422

# %%
loan.head()
loan.groupby('Loan_Amount_Term').count()
loan.groupby('Loan_Status').count()
loan.groupby('Credit_History').count()
loan.isnull().sum(axis=0)
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Loan_Status          0
# dtype: int64

# %%
loan.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         0.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Loan_Status
# 0             1.0            1
# 1             1.0            0
# 2             1.0            1
# 3             1.0            1
# 4             1.0            1

# %%
loan.groupby('Loan_Amount_Term').count()
# Out:
#                   ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Loan_Amount_Term
# 0.0                            14                 14          14
# 12.0                            1                  1           1
# 36.0                            2                  2           2
# 60.0                            2                  2           2
# 84.0                            4                  4           4
# 120.0                           3                  3           3
# 180.0                          44                 44          44
# 240.0                           4                  4           4
# 300.0                          13                 13          13
# 360.0                         512                512         512
# 480.0                          15                 15          15
#
#                   Credit_History  Loan_Status
# Loan_Amount_Term
# 0.0                           14           14
# 12.0                           1            1
# 36.0                           2            2
# 60.0                           2            2
# 84.0                           4            4
# 120.0                          3            3
# 180.0                         44           44
# 240.0                          4            4
# 300.0                         13           13
# 360.0                        512          512
# 480.0                         15           15

# %%
loan.groupby('Loan_Status').count()
# Out:
#              ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_Status
# 0                        192                192         192               192
# 1                        422                422         422               422
#
#              Credit_History
# Loan_Status
# 0                       192
# 1                       422

# %%
loan.groupby('Credit_History').count()
# Out:
#                 ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Credit_History
# 0.0                         139                139         139
# 1.0                         475                475         475
#
#                 Loan_Amount_Term  Loan_Status
# Credit_History
# 0.0                          139          139
# 1.0                          475          475

# %%
loan.isnull().sum(axis=0)
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Loan_Status          0
# dtype: int64

# %%
X = loan.iloc[:, :5].values

# %%
X
# Out:
# array([[5.849e+03, 0.000e+00, 0.000e+00, 3.600e+02, 1.000e+00],
#        [4.583e+03, 1.508e+03, 1.280e+02, 3.600e+02, 1.000e+00],
#        [3.000e+03, 0.000e+00, 6.600e+01, 3.600e+02, 1.000e+00],
#        ...,
#        [8.072e+03, 2.400e+02, 2.530e+02, 3.600e+02, 1.000e+00],
#        [7.583e+03, 0.000e+00, 1.870e+02, 3.600e+02, 1.000e+00],
#        [4.583e+03, 0.000e+00, 1.330e+02, 3.600e+02, 0.000e+00]])

# %%
X = loan.iloc[:, :5].values
y = loan.iloc[:, 5:].values

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-d18ed45d9350> in <module>
# ----> 1 from sklearn.cross_validation import train_test_split
#       2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0
-01,
#         -1.87697008e+00,  5.47206568e-01],
#        [-5.43320958e-01, -5.47719682e-01, -9.57750903e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-2.84163656e-01,  9.60856014e-01,  3.35504590e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-4.62079002e-01, -5.47719682e-01, -4.90440095e-01,
#          1.78339212e+00,  5.47206568e-01],
#        [-4.80536206e-01, -5.47719682e-01, -1.43592940e+00,
#          3.19247242e-01,  5.47206568e-01],
#        [-8.21332433e-03, -1.05774698e-01,  3.13769204e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-3.38778826e-01, -5.47719682e-01, -4.90440095e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-3.26070587e-01,  2.75102975e-02, -3.27424696e-01,
#         -1.87697008e+00,  5.47206568e-01],
#        [-3.04587612e-01, -5.47719682e-01, -3.16557003e-01,
#          3.19247242e-01, -1.82746344e+00],
#        [-4.29098096e-01, -5.47719682e-01, -7.73000118e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-3.36055632e-01, -5.47719682e-01, -7.73000118e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-2.20017307e-01, -5.47719682e-01, -1.86144685e-01,
#          3.19247242e-01, -1.82746344e+00],
#        [ 1.77139400e+00, -5.47719682e-01,  9.11492331e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-3.86434723e-01,  3.66297972e-02, -4.46969322e-01,
#          1.78339212e+00, -1.82746344e+00],
#        [-4.36965101e-01,  9.60505264e-01, -2.18747764e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [ 5.75306649e-01, -5.47719682e-01,  1.63962778e+00,
#          3.19247242e-01,  5.47206568e-01],
#        [ 2.22072102e+00, -5.47719682e-01,  3.68275410e+00,
#          3.19247242e-01,  5.47206568e-01],
#        [-4.64499619e-01,  2.59706789e-01, -4.48646727e-02,
#          3.19247242e-01,  5.47206568e-01],
#        [ 4.86615277e+00, -5.47719682e-01,  1.18150726e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [-2.97477050e-01, -5.47719682e-01, -3.38292390e-01,
#          3.19247242e-01, -1.82746344e+00],
#        [-6.13367561e-01,  8.36302955e-02, -4.14366242e-01,
#          3.19247242e-01, -1.82746344e+00],
#        [ 2.12879447e-02,  9.13855515e-01,  3.68107670e-01,
#          3.19247242e-01,  5.47206568e-01],
#        [ 8.45961881e-01, -5.47719682e-01, -5.57323659e-02,
#          3.19247242e-01,  5.47206568e-01],
#        [ 3.71732435e-02, -5.47719682e-01, -9.92031388e-02,
#          3.19247242e-01,  5.47206568e-01],
#        [-3.72970041e-01, -9.87596979e-02, -2.18747764e-01,
#          3.19247242e-01, -1.82746344e+00]])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(criterion = 'entropy', 
                                    max_depth=5, 
                                    min_samples_split=107, 
                                    min_samples_leaf=10, 
                                    max_features=None,  
                                    max_leaf_nodes=4,
                                    random_state = 0)

# %%
classifier
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=4, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=10,
#             min_samples_split=107, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=0, splitter='best')

# %%
classifier = DecisionTreeClassifier(criterion = 'gini', 
                                    max_depth=5, 
                                    min_samples_split=107, 
                                    min_samples_leaf=10, 
                                    max_features=None,  
                                    max_leaf_nodes=4,
                                    random_state = 0)

# %%
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=4, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=10,
#             min_samples_split=107, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=0, splitter='best')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[22, 21],
#        [15, 96]])

# %%
from sklearn.externals.six import StringIO

# %%
from sklearn import tree
from sklearn.tree import export_graphviz
from IPython.display import Image

# %%
import pydotplus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-b7d16578ff11> in <module>
# ----> 1 import pydotplus
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_pdf('loan_tree4.pdf')
#!dot -Tpng tree.dot -o tree.png -Gdpi=600
#pwd
Image(graph.create_png())
